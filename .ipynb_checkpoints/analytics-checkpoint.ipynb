# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2020/05
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM:
#
# ##### Semester: 2020/02
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Felipe Campos
# - Gabriel Albino
# - Helena Bretas
# - Lucas Machado
# - Cibele Freitas
# - Cristian Furtado
# - Eduarda Rodrigues
# - João Pedro Lyra
# - Mariana Oliveira
# - Rafael Fernandes

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json
from glob import glob
import os

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %% [markdown]
# ##### repo names, lenguage and path to the folder with all your jsons

# %%
#insert the repo names and used lenguages

repos = ['frontend', 'gateway', 'etl_tse', 'etl_twitter', 'etl_camara', 'etl_news']
language = [['frontend', 'js'], 
            ['gateway', 'py'], 
            ['etl_tse', 'py'], 
            ['etl_twitter', 'py'], 
            ['etl_camara', 'py'], 
            ['etl_news', 'py']]

repos_lenguage = {}

for item in language:
    repos_lenguage[f"{item[0]}"] = item[1]

# %%
repos_lenguage
# Out:
# {'frontend': 'js',
#  'gateway': 'py',
#  'etl_tse': 'py',
#  'etl_twitter': 'py',
#  'etl_camara': 'py',
#  'etl_news': 'py'}

# %%
jsons = glob('analytics-raw-data/*.json') # add the path here

# %%
# read the json files
def read_json(json_path):
    
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
        
    return json_obj

# creates the base dataframe
def create_base_component_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        base_component = read_json(i)

        base_component_data = base_component['baseComponent']['measures']

        base_component_df = pd.DataFrame(base_component_data)

        base_component_df['filename'] = os.path.basename(i)

        df = df.append(base_component_df, ignore_index=True)
        
    aux_df = df['filename'].str.split(r"fga-eps-mds-2020_2-(.*?)-(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df, repos

# %% [markdown]
# #### Create base component dataframe and repos list

# %%
base_component_df, repos = create_base_component_df(jsons)

# %%
# converts the dataframe version column to datetime format for future ordering
base_component_df['version'] =  pd.to_datetime(base_component_df['version'], format='%d-%m-%Y(%H)')
base_component_df = base_component_df.sort_values(by=['version'], ascending=True)

# %% [markdown]
# #### Create dataframe per file

# %%
#defines list of metrics
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

# %%
def metric_per_file(json):
    
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

# %%
def generate_file_dataframe_per_release(metric_list, json, language_extension):
    
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

# %%
def create_file_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        file_component = read_json(i)
        file_component_data = metric_per_file(file_component)
        file_name = os.path.basename(i)
               
        file_repository = file_name.split("-", 5)[4]
        file_lenguage = repos_lenguage[f"{file_repository}"]
        
        file_component_df = generate_file_dataframe_per_release(metric_list, 
                                                                file_component_data,
                                                                language_extension = file_lenguage)
        file_component_df['filename'] = file_name

        df = df.append(file_component_df, ignore_index=True)
        
    # replace TeamName by yours.    
    aux_df = df['filename'].str.split(r"fga-eps-mds-2020_2-(.*?)-(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[2]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df

# %%
file_component_df = create_file_df(jsons)

# %%
# converts the dataframe version column to datetime format for future ordering
file_component_df['version'] =  pd.to_datetime(file_component_df['version'], format='%d-%m-%Y(%H)')
file_component_df = file_component_df.sort_values(by=['version'], ascending=True)

# %%
file_component_df.to_excel('data/data.xlsx', index = False)

# %%
file_component_df
# Out:
#                                                   path functions complexity  \
# 517                             src/twitter/twitter.py         3          3
# 50                          src/screens/PartyScreen.js         1          1
# 49            src/components/ActivityListItem/index.js         1          1
# 48                     src/screens/HomeScreen/index.js         2          2
# 47                                        src/index.js         0          0
# 46                           src/screens/HomeScreen.js         1          1
# 45                          src/screens/ErrorScreen.js         1          1
# 44                  src/screens/DeputyProfileScreen.js         1          1
# 43                       src/screens/DeputiesScreen.js         1          1
# 42         src/components/DeputiesList/DeputiesList.js         2          2
# 230                                src/api/__init__.py         0          0
# 231                                src/etl/__init__.py         0          0
# 232                                     src/api/api.py         2         12
# 51                       src/screens/ProjectsScreen.js         1          1
# 233                                         src/app.py         1          2
# 41            src/components/Breadcrumb/Breadcrumbs.js         5          7
# 40                                          src/App.js         1          1
# 516                                     src/tse/tse.py         2          2
# 537                                      src/models.py         0          0
# 536                                         src/app.py         1          2
# 535                                     src/api/api.py         2          4
# 534                                src/etl/__init__.py         0          0
# 533                                src/api/__init__.py         0          0
# 65                                       src/models.py         2          2
# 64                                          src/app.py         1          2
# 63                                      src/api/api.py         1          2
# 62                                 src/etl/__init__.py         0          0
# 234                                      src/models.py         2          2
# 52            src/screens/SearchScreen/SearchFilter.js         1          1
# 61                                 src/api/__init__.py         0          0
# 54                     src/components/TopBar/TopBar.js         5         12
# 55                       src/components/Tweet/Tweet.js         2          2
# 53                         src/screens/SearchScreen.js         1          1
# 509                               src/news/__init__.py         0          0
# 510                                src/tse/__init__.py         0          0
# 515                                   src/news/news.py         2          2
# 514                               src/camara/camara.py         3          3
# 513                                         src/app.py         1          2
# 512                            src/twitter/__init__.py         0          0
# 511                             src/camara/__init__.py         0          0
# 478                                   src/news/news.py         4          4
# 481                                         src/Api.js         1          2
# 482                                         src/App.js         1          1
# 485      src/components/DataVoting/DataVotingMobile.js         2          2
# 484            src/components/DataVoting/DataVoting.js         1          1
# 66                                 src/api/__init__.py         0          0
# 486        src/components/DeputiesList/DeputiesList.js         2          2
# 487                      src/screens/DeputiesScreen.js         1          1
# 488                         src/screens/ErrorScreen.js         1          1
# 489                                       src/index.js         0          0
# 483  src/components/Breadcrumbs/tests/breadcrumbs.t...         1          1
# 67                                 src/etl/__init__.py         0          0
# 480                             src/twitter/twitter.py         2          2
# 69                                          src/app.py         1          2
# 70                                       src/models.py         2          2
# 479                                     src/tse/tse.py         2          2
# 566                                      src/models.py         2          2
# 532                                      src/models.py         2          2
# 531                                         src/app.py         1          2
# 530                                     src/api/api.py        10         37
# 529                                src/etl/__init__.py         0          0
# 528                                src/api/__init__.py         0          0
# 562                                src/api/__init__.py         0          0
# 563                                src/etl/__init__.py         0          0
# 564                                     src/api/api.py         1          2
# 565                                         src/app.py         1          2
# 68                                      src/api/api.py         6         28
# 491           src/screens/DeputyProfileScreen/index.js         3          3
# 490                    src/screens/HomeScreen/index.js         4          4
# 493                     src/components/TopBar/index.js         7         22
# 475                            src/twitter/__init__.py         0          0
# 474                             src/camara/__init__.py         0          0
# 473                                src/tse/__init__.py         0          0
# 472                               src/news/__init__.py         0          0
# 224                                      src/models.py         3          3
# 492                      src/components/Tweet/index.js         2          2
# 223                                         src/app.py         1          2
# 222                                     src/api/api.py        21         69
# 221                                src/etl/__init__.py         0          0
# 220                                src/api/__init__.py         0          0
# 476                                         src/app.py         1          2
# 477                               src/camara/camara.py         8          8
# 508                  src/components/DataVoting/Vote.js         1          1
# 507        src/components/SpentData/SpentDataMobile.js         1          1
# 505                        src/screens/SearchScreen.js         5          8
# 506              src/components/SpentData/SpentData.js         2          2
# 494           src/components/ActivityListItem/index.js         1          2
# 495               src/components/DeputiesList/index.js         2          4
# 496                src/components/ShareButton/index.js         5          5
# 497               src/components/SearchFilter/index.js         3          5
# 498                src/components/Breadcrumbs/index.js         5          7
# 499                       src/components/News/index.js         4          5
# 504            src/components/SearchHome/SearchHome.js         2          2
# 500                         src/screens/PartyScreen.js         1          1
# 501                  src/components/Profile/Profile.js         4          5
# 502            src/components/Profile/ProfileMobile.js         1          1
# 503                      src/screens/ProjectsScreen.js         1          1
# 244                                         src/app.py         1          2
# 248                             src/twitter/twitter.py         2          2
# 368                                      src/models.py         2          2
# 367                                         src/app.py         1          2
# 366                                     src/api/api.py        10         37
# 365                                src/etl/__init__.py         0          0
# 364                                src/api/__init__.py         0          0
# 240                               src/news/__init__.py         0          0
# 241                                src/tse/__init__.py         0          0
# 242                             src/camara/__init__.py         0          0
# 117                                         src/Api.js         3          4
# 247                                     src/tse/tse.py         2          2
# 246                                   src/news/news.py         4          4
# 245                               src/camara/camara.py        11         11
# 243                            src/twitter/__init__.py         0          0
# 118                                         src/App.js         1          1
# 128           src/screens/DeputyProfileScreen/index.js         3          3
# 120            src/components/DataVoting/DataVoting.js         5          8
# 146        src/components/SpentData/SpentDataMobile.js         1          1
# 145              src/components/SpentData/SpentData.js         2          2
# 144                        src/screens/SearchScreen.js         5          8
# 143                      src/screens/ProjectsScreen.js         1          1
# 141                  src/components/Profile/Profile.js         6          7
# 140                         src/screens/PartyScreen.js         1          1
# 139                  src/components/News/NewsMobile.js         5          5
# 138                        src/components/News/News.js         6          6
# 137                   src/components/HomeNews/index.js         4          5
# 136                src/components/Breadcrumbs/index.js         5          7
# 135               src/components/SearchFilter/index.js         3          5
# 119  src/components/Breadcrumbs/tests/breadcrumbs.t...         1          1
# 134                 src/components/SearchHome/index.js         2          2
# 132               src/components/DeputiesList/index.js         2          4
# 131           src/components/ActivityListItem/index.js         1          2
# 130                     src/components/TopBar/index.js         7         22
# 129                      src/components/Tweet/index.js         2          2
# 127                    src/screens/HomeScreen/index.js         4          4
# 126                                       src/index.js         0          0
# 125                         src/screens/ErrorScreen.js         1          1
# 124                 src/screens/DeputyProfileScreen.js         4          4
# 123                      src/screens/DeputiesScreen.js         1          1
# 122        src/components/DeputiesList/DeputiesList.js         2          2
# 121      src/components/DataVoting/DataVotingMobile.js         4          4
# 133                src/components/ShareButton/index.js         5          5
# 142            src/components/Profile/ProfileMobile.js         1          1
# 254                                src/api/__init__.py         0          0
# 106                                         src/app.py         1          2
# 107                                      src/models.py         2          2
# 174                                         src/app.py         1          2
# 105                                     src/api/api.py         6         28
# 104                                src/etl/__init__.py         0          0
# 103                                src/api/__init__.py         0          0
# 173                                     src/api/api.py         1          2
# 175                                      src/models.py         2          2
# 172                                src/etl/__init__.py         0          0
# 258                                      src/models.py         4          4
# 257                                         src/app.py         1          2
# 256                                     src/api/api.py        25         82
# 255                                src/etl/__init__.py         0          0
# 171                                src/api/__init__.py         0          0
# 204              src/components/SpentData/SpentData.js         2          2
# 203                        src/screens/SearchScreen.js         5          8
# 410                                src/api/__init__.py         0          0
# 276                            src/twitter/__init__.py         0          0
# 412                                     src/api/api.py         1          2
# 202                      src/screens/ProjectsScreen.js         1          1
# 413                                         src/app.py         1          2
# 414                                      src/models.py         2          2
# 205        src/components/SpentData/SpentDataMobile.js         1          1
# 281                             src/twitter/twitter.py         2          2
# 280                                     src/tse/tse.py         2          2
# 411                                src/etl/__init__.py         0          0
# 201            src/components/Profile/ProfileMobile.js         1          1
# 198                  src/components/News/NewsMobile.js         5          5
# 199                         src/screens/PartyScreen.js         1          1
# 193                 src/components/SearchHome/index.js         2          2
# 192                src/components/ShareButton/index.js         5          5
# 191               src/components/DeputiesList/index.js         2          4
# 190           src/components/ActivityListItem/index.js         1          2
# 189                     src/components/TopBar/index.js         7         22
# 188                      src/components/Tweet/index.js         2          2
# 187           src/screens/DeputyProfileScreen/index.js         3          3
# 186                    src/screens/HomeScreen/index.js         4          4
# 185                                       src/index.js         0          0
# 184                         src/screens/ErrorScreen.js         1          1
# 183                 src/screens/DeputyProfileScreen.js         4          4
# 182                      src/screens/DeputiesScreen.js         1          1
# 181        src/components/DeputiesList/DeputiesList.js         2          2
# 180      src/components/DataVoting/DataVotingMobile.js         4          4
# 179            src/components/DataVoting/DataVoting.js         5          8
# 178  src/components/Breadcrumbs/tests/breadcrumbs.t...         1          1
# 177                                         src/App.js         1          1
# 176                                         src/Api.js         3          4
# 196                   src/components/HomeNews/index.js         4          5
# 197                        src/components/News/News.js         6          6
# 279                                   src/news/news.py         4          4
# 200                  src/components/Profile/Profile.js         6          7
# 278                               src/camara/camara.py        11         11
# 195                src/components/Breadcrumbs/index.js         5          7
# 194               src/components/SearchFilter/index.js         3          5
# 567                                src/api/__init__.py         0          0
# 568                                src/etl/__init__.py         0          0
# 569                                     src/api/api.py        25         82
# 56                                 src/api/__init__.py         0          0
# 57                                 src/etl/__init__.py         0          0
# 58                                      src/api/api.py        10         37
# 59                                          src/app.py         1          2
# 60                                       src/models.py         2          2
# 277                                         src/app.py         1          2
# 571                                      src/models.py         4          4
# 358                                      src/models.py         2          2
# 357                                         src/app.py         1          2
# 356                                     src/api/api.py         6         28
# 570                                         src/app.py         1          2
# 354                                src/api/__init__.py         0          0
# 273                               src/news/__init__.py         0          0
# 355                                src/etl/__init__.py         0          0
# 275                             src/camara/__init__.py         0          0
# 274                                src/tse/__init__.py         0          0
# 10         src/components/DeputiesList/DeputiesList.js         2          2
# 9        src/components/DataVoting/DataVotingMobile.js         4          4
# 8              src/components/DataVoting/DataVoting.js         5          8
# 7    src/components/Breadcrumbs/tests/breadcrumbs.t...         1          1
# 27                   src/components/News/NewsMobile.js         5          5
# 34         src/components/SpentData/SpentDataMobile.js         1          1
# 33               src/components/SpentData/SpentData.js         2          2
# 32                         src/screens/SearchScreen.js         5          8
# 31                       src/screens/ProjectsScreen.js         1          1
# 30             src/components/Profile/ProfileMobile.js         1          1
# 29                   src/components/Profile/Profile.js         6          7
# 6                                           src/App.js         1          1
# 26                         src/components/News/News.js         6          6
# 24                 src/components/Breadcrumbs/index.js         5          7
# 13                          src/screens/ErrorScreen.js         1          1
# 12                  src/screens/DeputyProfileScreen.js         4          4
# 14                                        src/index.js         0          0
# 15                     src/screens/HomeScreen/index.js         5          5
# 16            src/screens/DeputyProfileScreen/index.js         3          3
# 17                       src/components/Tweet/index.js         2          2
# 25                    src/components/HomeNews/index.js         4          5
# 18                      src/components/TopBar/index.js         7         22
# 5                                           src/Api.js         3          4
# 19            src/components/ActivityListItem/index.js         1          2
# 20                src/components/DeputiesList/index.js         2          4
# 21                 src/components/ShareButton/index.js         5          5
# 22                  src/components/SearchHome/index.js         2          2
# 23                src/components/SearchFilter/index.js         3          5
# 11                       src/screens/DeputiesScreen.js         1          1
# 28                          src/screens/PartyScreen.js         1          1
# 159                                     src/tse/tse.py         2          2
# 576                                      src/models.py         2          2
# 206                                src/api/__init__.py         0          0
# 207                                src/etl/__init__.py         0          0
# 208                                     src/api/api.py        10         37
# 209                                         src/app.py         1          2
# 210                                      src/models.py         2          2
# 575                                         src/app.py         1          2
# 574                                     src/api/api.py         6         28
# 573                                src/etl/__init__.py         0          0
# 572                                src/api/__init__.py         0          0
# 538                                src/api/__init__.py         0          0
# 539                                src/etl/__init__.py         0          0
# 541                                         src/app.py         1          2
# 542                                      src/models.py         4          4
# 540                                     src/api/api.py        25         82
# 458                                src/etl/__init__.py         0          0
# 160                             src/twitter/twitter.py         2          2
# 156                                         src/app.py         1          2
# 153                                src/tse/__init__.py         0          0
# 461                                      src/models.py         2          2
# 158                                   src/news/news.py         4          4
# 460                                         src/app.py         1          2
# 459                                     src/api/api.py         1          2
# 157                               src/camara/camara.py        11         11
# 457                                src/api/__init__.py         0          0
# 154                             src/camara/__init__.py         0          0
# 155                            src/twitter/__init__.py         0          0
# 152                               src/news/__init__.py         0          0
# 342                        src/components/News/News.js         6          6
# 341                   src/components/HomeNews/index.js         4          5
# 351                        src/screens/SearchScreen.js         5          8
# 350   src/components/Proposition/PropositionsMobile.js         1          2
# 345                  src/components/Profile/Profile.js         6          7
# 348          src/components/Proposition/Proposition.js         6         12
# 347                      src/screens/ProjectsScreen.js         1          1
# 346            src/components/Profile/ProfileMobile.js         1          1
# 352              src/components/SpentData/SpentData.js        14         25
# 344                         src/screens/PartyScreen.js         1          1
# 343                  src/components/News/NewsMobile.js         5          5
# 349                   src/screens/PropositionScreen.js         3          3
# 353        src/components/SpentData/SpentDataMobile.js         7          7
# 548                            src/twitter/__init__.py         0          0
# 551                             src/camara/__init__.py         0          0
# 471                                      src/models.py         2          2
# 550                                src/tse/__init__.py         0          0
# 470                                         src/app.py         1          2
# 469                                     src/api/api.py         6         28
# 468                                src/etl/__init__.py         0          0
# 467                                src/api/__init__.py         0          0
# 549                               src/news/__init__.py         0          0
# 363                                      src/models.py         4          4
# 362                                         src/app.py         1          2
# 361                                     src/api/api.py        25         82
# 340                src/components/Breadcrumbs/index.js        10         16
# 552                                         src/app.py         1          2
# 339               src/components/SearchFilter/index.js         3          5
# 327                      src/screens/DeputiesScreen.js         1          1
# 337                 src/components/SearchHome/index.js         2          2
# 464                                     src/api/api.py        10         37
# 465                                         src/app.py         1          2
# 466                                      src/models.py         2          2
# 359                                src/api/__init__.py         0          0
# 360                                src/etl/__init__.py         0          0
# 451                                      src/models.py         2          2
# 450                                         src/app.py         1          2
# 323                                         src/App.js         1          1
# 322                                         src/Api.js         6          7
# 449                                     src/api/api.py         1          2
# 554                                   src/news/news.py         4          4
# 555                                     src/tse/tse.py         2          2
# 556                             src/twitter/twitter.py         2          2
# 448                                src/etl/__init__.py         0          0
# 447                                src/api/__init__.py         0          0
# 463                                src/etl/__init__.py         0          0
# 462                                src/api/__init__.py         0          0
# 338                src/components/ShareButton/index.js         5          6
# 329                      src/screens/ExpensesScreen.js         1          1
# 336               src/components/DeputiesList/index.js         2          4
# 335                      src/components/Tweet/index.js         2          2
# 334           src/components/ActivityListItem/index.js         1          2
# 324            src/components/DataVoting/DataVoting.js         6         10
# 333                     src/components/TopBar/index.js         7         22
# 332           src/screens/DeputyProfileScreen/index.js         3          3
# 331                    src/screens/HomeScreen/index.js         5          5
# 330                                       src/index.js         0          0
# 325      src/components/DataVoting/DataVotingMobile.js         4          4
# 326        src/components/DeputiesList/DeputiesList.js         2          2
# 328                         src/screens/ErrorScreen.js         1          1
# 553                               src/camara/camara.py        11         11
# 284                                     src/api/api.py         1          2
# 283                                src/etl/__init__.py         0          0
# 578                                src/etl/__init__.py         0          0
# 285                                         src/app.py         1          2
# 282                                src/api/__init__.py         0          0
# 286                                      src/models.py         2          2
# 271                                     src/tse/tse.py         2          2
# 577                                src/api/__init__.py         0          0
# 579                                     src/api/api.py         6         28
# 580                                         src/app.py         1          2
# 581                                      src/models.py         2          2
# 518                                src/api/__init__.py         0          0
# 519                                src/etl/__init__.py         0          0
# 520                                     src/api/api.py        16         53
# 270                                   src/news/news.py         4          4
# 269                               src/camara/camara.py        11         11
# 547                                      src/models.py         4          4
# 546                                         src/app.py         1          2
# 545                                     src/api/api.py        25         82
# 544                                src/etl/__init__.py         0          0
# 543                                src/api/__init__.py         0          0
# 272                             src/twitter/twitter.py         3          3
# 522                                      src/models.py         4          4
# 521                                         src/app.py         1          2
# 267                             src/camara/__init__.py         0          0
# 266                                src/tse/__init__.py         0          0
# 370                                         src/App.js         1          1
# 371            src/components/DataVoting/DataVoting.js         6         10
# 372      src/components/DataVoting/DataVotingMobile.js         4          4
# 373        src/components/DeputiesList/DeputiesList.js         2          2
# 374                      src/screens/DeputiesScreen.js         1          1
# 268                                         src/app.py         1          2
# 375                         src/screens/ErrorScreen.js         1          1
# 376                      src/screens/ExpensesScreen.js         1          1
# 377                                       src/index.js         0          0
# 378                    src/screens/HomeScreen/index.js         5          5
# 379           src/screens/DeputyProfileScreen/index.js         3          3
# 385                src/components/ShareButton/index.js         5          6
# 384                 src/components/SearchHome/index.js         2          2
# 383               src/components/DeputiesList/index.js         2          4
# 382                      src/components/Tweet/index.js         2          2
# 369                                         src/Api.js         6          7
# 381           src/components/ActivityListItem/index.js         1          2
# 386               src/components/SearchFilter/index.js         3          5
# 388                   src/components/HomeNews/index.js         4          5
# 265                               src/news/__init__.py         0          0
# 264                            src/twitter/__init__.py         0          0
# 400        src/components/SpentData/SpentDataMobile.js         7          7
# 399              src/components/SpentData/SpentData.js        14         25
# 398                        src/screens/SearchScreen.js         5          8
# 397   src/components/Proposition/PropositionsMobile.js         1          2
# 396                   src/screens/PropositionScreen.js         3          3
# 387                src/components/Breadcrumbs/index.js        10         16
# 395          src/components/Proposition/Proposition.js         6         12
# 393            src/components/Profile/ProfileMobile.js         1          1
# 392                  src/components/Profile/Profile.js         6          7
# 391                         src/screens/PartyScreen.js         1          1
# 390                  src/components/News/NewsMobile.js         5          5
# 389                        src/components/News/News.js         6          6
# 394                      src/screens/ProjectsScreen.js         1          1
# 380                     src/components/TopBar/index.js         7         22
# 148                                src/etl/__init__.py         0          0
# 149                                     src/api/api.py         6         28
# 147                                src/api/__init__.py         0          0
# 404                             src/camara/__init__.py         0          0
# 408                                     src/tse/tse.py         2          2
# 407                                   src/news/news.py         4          4
# 406                               src/camara/camara.py        11         11
# 405                                         src/app.py         1          2
# 403                                src/tse/__init__.py         0          0
# 402                               src/news/__init__.py         0          0
# 39                                       src/models.py         4          4
# 38                                          src/app.py         1          2
# 37                                      src/api/api.py        25         82
# 36                                 src/etl/__init__.py         0          0
# 35                                 src/api/__init__.py         0          0
# 401                            src/twitter/__init__.py         0          0
# 150                                         src/app.py         1          2
# 409                             src/twitter/twitter.py         3          3
# 151                                      src/models.py         2          2
# 83            src/components/ActivityListItem/index.js         1          2
# 96                       src/screens/ProjectsScreen.js         1          1
# 87                 src/components/ShareButton/index.js         5          6
# 88                src/components/SearchFilter/index.js         3          5
# 89                 src/components/Breadcrumbs/index.js        10         16
# 90                    src/components/HomeNews/index.js         4          5
# 91                         src/components/News/News.js         6          6
# 92                   src/components/News/NewsMobile.js         5          5
# 86                  src/components/SearchHome/index.js         2          2
# 93                          src/screens/PartyScreen.js         1          1
# 95             src/components/Profile/ProfileMobile.js         1          1
# 97           src/components/Proposition/Proposition.js         6         12
# 98                    src/screens/PropositionScreen.js         3          3
# 99    src/components/Proposition/PropositionsMobile.js         1          2
# 100                        src/screens/SearchScreen.js         5          8
# 101              src/components/SpentData/SpentData.js        14         25
# 94                   src/components/Profile/Profile.js         6          7
# 102        src/components/SpentData/SpentDataMobile.js         7          7
# 85                src/components/DeputiesList/index.js         2          4
# 82                      src/components/TopBar/index.js         7         22
# 2                                       src/api/api.py         1          2
# 3                                           src/app.py         1          2
# 4                                        src/models.py         2          2
# 71                                          src/Api.js         6          7
# 72                                          src/App.js         1          1
# 73             src/components/DataVoting/DataVoting.js         6         10
# 84                       src/components/Tweet/index.js         2          2
# 74       src/components/DataVoting/DataVotingMobile.js         4          4
# 76                       src/screens/DeputiesScreen.js         1          1
# 77                          src/screens/ErrorScreen.js         1          1
# 78                       src/screens/ExpensesScreen.js         1          1
# 79                                        src/index.js         0          0
# 80                     src/screens/HomeScreen/index.js         5          5
# 81            src/screens/DeputyProfileScreen/index.js         3          3
# 75         src/components/DeputiesList/DeputiesList.js         2          2
# 1                                  src/etl/__init__.py         0          0
# 0                                  src/api/__init__.py         0          0
# 527                                      src/models.py         4          4
# 526                                         src/app.py         1          2
# 525                                     src/api/api.py        16         53
# 524                                src/etl/__init__.py         0          0
# 523                                src/api/__init__.py         0          0
# 444                        src/screens/SearchScreen.js         5          8
# 218                                     src/tse/tse.py         2          2
# 217                                   src/news/news.py         4          4
# 219                             src/twitter/twitter.py         4          4
# 216                               src/camara/camara.py        11         11
# 214                             src/camara/__init__.py         0          0
# 445              src/components/SpentData/SpentData.js        14         25
# 212                               src/news/__init__.py         0          0
# 415                                         src/Api.js         8          9
# 416                                         src/App.js         1          1
# 417            src/components/DataVoting/DataVoting.js         6         10
# 418      src/components/DataVoting/DataVotingMobile.js         4          4
# 215                                         src/app.py         1          2
# 169                                         src/app.py         1          2
# 166                                src/api/__init__.py         0          0
# 167                                src/etl/__init__.py         0          0
# 452                                src/api/__init__.py         0          0
# 226                                src/etl/__init__.py         0          0
# 227                                     src/api/api.py         1          2
# 228                                         src/app.py         1          2
# 229                                      src/models.py         2          2
# 161                                src/api/__init__.py         0          0
# 162                                src/etl/__init__.py         0          0
# 163                                     src/api/api.py         6         28
# 164                                         src/app.py         1          2
# 165                                      src/models.py         2          2
# 225                                src/api/__init__.py         0          0
# 168                                     src/api/api.py        17         56
# 453                                src/etl/__init__.py         0          0
# 213                                src/tse/__init__.py         0          0
# 455                                         src/app.py         1          2
# 427                     src/components/TopBar/index.js         7         22
# 428           src/components/ActivityListItem/index.js         1          2
# 429                      src/components/Tweet/index.js         2          4
# 430               src/components/DeputiesList/index.js         2          4
# 431                 src/components/SearchHome/index.js         2          2
# 432                src/components/ShareButton/index.js         5          6
# 433               src/components/SearchFilter/index.js         3          5
# 434                src/components/Breadcrumbs/index.js        10         16
# 435                   src/components/HomeNews/index.js         4          5
# 436                        src/components/News/News.js         6          6
# 437                  src/components/News/NewsMobile.js         5          5
# 438                         src/screens/PartyScreen.js         1          1
# 439                  src/components/Profile/Profile.js         6          7
# 440            src/components/Profile/ProfileMobile.js         1          1
# 441                      src/screens/ProjectsScreen.js         1          1
# 442          src/components/Proposition/Proposition.js         6         13
# 443   src/components/Proposition/PropositionsMobile.js         1          3
# 426             src/screens/PropositionScreen/index.js         4          4
# 454                                     src/api/api.py        25         82
# 425           src/screens/DeputyProfileScreen/index.js         4          4
# 446        src/components/SpentData/SpentDataMobile.js         7          7
# 456                                      src/models.py         4          4
# 170                                      src/models.py         4          4
# 211                            src/twitter/__init__.py         0          0
# 419        src/components/DeputiesList/DeputiesList.js         2          2
# 420                      src/screens/DeputiesScreen.js         1          1
# 422                      src/screens/ExpensesScreen.js         1          1
# 423                                       src/index.js         0          0
# 424                    src/screens/HomeScreen/index.js         5          5
# 421                         src/screens/ErrorScreen.js         1          1
# 109                               src/news/__init__.py         0          0
# 559                                     src/api/api.py         1          2
# 558                                src/etl/__init__.py         0          0
# 557                                src/api/__init__.py         0          0
# 116                             src/twitter/twitter.py         4          4
# 237                                     src/api/api.py        17         56
# 236                                src/etl/__init__.py         0          0
# 108                            src/twitter/__init__.py         0          0
# 235                                src/api/__init__.py         0          0
# 239                                      src/models.py         4          4
# 112                                         src/app.py         1          2
# 111                             src/camara/__init__.py         0          0
# 114                                   src/news/news.py         4          4
# 110                                src/tse/__init__.py         0          0
# 238                                         src/app.py         1          2
# 113                               src/camara/camara.py        11         11
# 115                                     src/tse/tse.py         2          2
# 290            src/components/DataVoting/DataVoting.js         6         10
# 252                                         src/app.py         1          2
# 309                   src/components/HomeNews/index.js         4          5
# 308                src/components/Breadcrumbs/index.js        10         16
# 307               src/components/SearchFilter/index.js         3          5
# 306                src/components/ShareButton/index.js         5          6
# 305                 src/components/SearchHome/index.js         2          2
# 304               src/components/DeputiesList/index.js         2          4
# 303                      src/components/Tweet/index.js         2          4
# 302           src/components/ActivityListItem/index.js         1          2
# 301                     src/components/TopBar/index.js         7         22
# 300             src/screens/PropositionScreen/index.js         4          4
# 299           src/screens/DeputyProfileScreen/index.js         4          4
# 298                    src/screens/HomeScreen/index.js         5          5
# 297                                       src/index.js         0          0
# 296                    src/components/Charts/Format.js         3          3
# 295                      src/screens/ExpensesScreen.js         1          1
# 294                         src/screens/ErrorScreen.js         1          1
# 293                      src/screens/DeputiesScreen.js         1          1
# 292        src/components/DeputiesList/DeputiesList.js         2          2
# 291      src/components/DataVoting/DataVotingMobile.js         4          4
# 310                     src/components/Charts/index.js         7          9
# 311                        src/components/News/News.js         6          6
# 312                  src/components/News/NewsMobile.js         5          5
# 313                         src/screens/PartyScreen.js         1          1
# 251                                     src/api/api.py         6         28
# 250                                src/etl/__init__.py         0          0
# 249                                src/api/__init__.py         0          0
# 561                                      src/models.py         2          2
# 289                  src/components/Charts/ChartPie.js         3          3
# 259                                src/api/__init__.py         0          0
# 260                                src/etl/__init__.py         0          0
# 261                                     src/api/api.py        25         82
# 262                                         src/app.py         1          2
# 253                                      src/models.py         2          2
# 263                                      src/models.py         4          4
# 288                                         src/App.js         1          1
# 321        src/components/SpentData/SpentDataMobile.js         8         10
# 320              src/components/SpentData/SpentData.js        17         32
# 319                        src/screens/SearchScreen.js         5          8
# 318   src/components/Proposition/PropositionsMobile.js         1          3
# 317          src/components/Proposition/Proposition.js         6         13
# 316                      src/screens/ProjectsScreen.js         1          1
# 315            src/components/Profile/ProfileMobile.js         1          1
# 314                  src/components/Profile/Profile.js         6          7
# 287                                         src/Api.js         8          9
# 560                                         src/app.py         1          2
#
#     comment_lines_density duplicated_lines_density coverage ncloc  \
# 517                   0.0                      0.0      0.0    22
# 50                    0.0                      0.0      0.0    10
# 49                   10.5                      0.0      0.0    34
# 48                   11.3                      0.0      0.0    94
# 47                    0.0                      0.0      0.0    13
# 46                    0.0                      0.0      0.0     8
# 45                    0.0                      0.0      0.0     9
# 44                    0.0                      0.0      0.0    15
# 43                    0.0                      0.0      0.0    10
# 42                    0.0                      0.0      0.0    24
# 230                   NaN                      0.0      NaN     0
# 231                   NaN                      0.0      NaN     0
# 232                  17.0                      0.0      0.0    39
# 51                    0.0                      0.0      0.0    10
# 233                   0.0                      0.0      0.0    20
# 41                    0.0                      0.0      0.0    36
# 40                    0.0                      0.0      0.0    30
# 516                   0.0                      0.0      0.0    16
# 537                  26.3                      0.0      0.0    28
# 536                   0.0                      0.0      0.0    20
# 535                   0.0                      0.0      0.0    14
# 534                   NaN                      0.0      NaN     0
# 533                   NaN                      0.0      NaN     0
# 65                    0.0                      0.0      0.0    63
# 64                    0.0                      0.0      0.0    19
# 63                    6.3                      0.0      0.0    15
# 62                    NaN                      0.0      NaN     0
# ...
# 192     frontend 2021-05-02 00:00:00
# 191     frontend 2021-05-02 00:00:00
# 190     frontend 2021-05-02 00:00:00
# 189     frontend 2021-05-02 00:00:00
# 188     frontend 2021-05-02 00:00:00
# 187     frontend 2021-05-02 00:00:00
# 236  etl_twitter 2021-05-10 01:00:00
# 108      gateway 2021-05-10 01:00:00
# 235  etl_twitter 2021-05-10 01:00:00
# 239  etl_twitter 2021-05-10 01:00:00
# 112      gateway 2021-05-10 01:00:00
# 111      gateway 2021-05-10 01:00:00
# 114      gateway 2021-05-10 01:00:00
# 110      gateway 2021-05-10 01:00:00
# 238  etl_twitter 2021-05-10 01:00:00
# 113      gateway 2021-05-10 01:00:00
# 115      gateway 2021-05-10 01:00:00
# 290     frontend 2021-05-10 01:00:00
# 252     etl_news 2021-05-10 01:00:00
# 309     frontend 2021-05-10 01:00:00
# 308     frontend 2021-05-10 01:00:00
# 307     frontend 2021-05-10 01:00:00
# 306     frontend 2021-05-10 01:00:00
# 305     frontend 2021-05-10 01:00:00
# 304     frontend 2021-05-10 01:00:00
# 303     frontend 2021-05-10 01:00:00
# 302     frontend 2021-05-10 01:00:00
# 301     frontend 2021-05-10 01:00:00
# 300     frontend 2021-05-10 01:00:00
# 299     frontend 2021-05-10 01:00:00
# 298     frontend 2021-05-10 01:00:00
# 297     frontend 2021-05-10 01:00:00
# 296     frontend 2021-05-10 01:00:00
# 295     frontend 2021-05-10 01:00:00
# 294     frontend 2021-05-10 01:00:00
# 293     frontend 2021-05-10 01:00:00
# 292     frontend 2021-05-10 01:00:00
# 291     frontend 2021-05-10 01:00:00
# 310     frontend 2021-05-10 01:00:00
# 311     frontend 2021-05-10 01:00:00
# 312     frontend 2021-05-10 01:00:00
# 313     frontend 2021-05-10 01:00:00
# 251     etl_news 2021-05-10 01:00:00
# 250     etl_news 2021-05-10 01:00:00
# 249     etl_news 2021-05-10 01:00:00
# 561      etl_tse 2021-05-10 01:00:00
# 289     frontend 2021-05-10 01:00:00
# 259   etl_camara 2021-05-10 01:00:00
# 260   etl_camara 2021-05-10 01:00:00
# 261   etl_camara 2021-05-10 01:00:00
# 262   etl_camara 2021-05-10 01:00:00
# 253     etl_news 2021-05-10 01:00:00
# 263   etl_camara 2021-05-10 01:00:00
# 288     frontend 2021-05-10 01:00:00
# 321     frontend 2021-05-10 01:00:00
# 320     frontend 2021-05-10 01:00:00
# 319     frontend 2021-05-10 01:00:00
# 318     frontend 2021-05-10 01:00:00
# 317     frontend 2021-05-10 01:00:00
# 316     frontend 2021-05-10 01:00:00
# 315     frontend 2021-05-10 01:00:00
# 314     frontend 2021-05-10 01:00:00
# 287     frontend 2021-05-10 01:00:00
# 560      etl_tse 2021-05-10 01:00:00

# %% [markdown]
# #### Create dataframe per repository

# %%
# create one dataframe for each repo
repository_dataframes = {} 

for repository in repos:
    df = file_component_df[file_component_df['repository'] == f"{repository}"]
    df.name = f"{repository}"
    repository_dataframes[f"{repository}"] = df

# %% [markdown]
# ### Metric calculations

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df)
    
    return duplication

# %% [markdown]
# ### Calculate m1, m2 and m3 for each repository

# %%
def create_metrics_df(df):
    
    version_vec = df['version'].unique()
    
    m1_list = []
    m2_list = []
    m3_list = []
    repository_list = []
    version_list = []
    
    metrics_df = pd.DataFrame()
    
    for version in version_vec:

        version_df = df[df['version'] == version]

        m1_list.append(m1(version_df))
        m2_list.append(m2(version_df))
        m3_list.append(m3(version_df))
        repository_list.append(version_df['repository'].iloc[0])
        version_list.append(version)
        
    metrics_df = pd.DataFrame({'m1': m1_list,
                               'm2': m2_list,
                               'm3': m3_list,
                               'repository': repository_list, 
                               'version': version_list})
        
    return metrics_df

# %%
repository_metrics = {}

for repository, repo_df in repository_dataframes.items():   
    metrics_df = create_metrics_df(repo_df)
    metrics_df.name = f"{repository}"
    repository_metrics[f"{repository}"] = metrics_df

# %% [markdown]
# ##  PRODUCTIVITY

# %% [markdown]
# ### TIMEFRAME: PUT_YOUR_TIMEFRAME_HERE

# %%
NUMBER_OF_ISSUES_RESOLVED = 7
NUMBER_OF_ISSUES = 50

TAGS = {
    "HOTFIX": 4,
    "DOCS": 2,
    "FEATURE": 3,
    "ARQ": 2,
    "DEVOPS": 5,
    "ANALYTICS": 2,
    "US": 4,
    "EASY": 9,
    "MEDIUM": 1,
    "HARD": 2,
    "EPS": 5,
    "MDS": 7
}

# %% [markdown]
# #### RESOLVED ISSUES' THROUGHPUT

# %%
def m7(number_of_issues_resolved, number_of_issues):
    
    resolved_issues_throughput = round((number_of_issues_resolved / number_of_issues) * 100, 2)
    
    return resolved_issues_throughput

# %% [markdown]
# #### ISSUE TYPE IN A TIMEFRAME

# %%
def density(issue, number_of_issues):
    issue_density = round((issue / number_of_issues) * 100, 2)
    return issue_density

def m8(tag_dict, number_of_issues):
    
    issue_densities = {
        "hotfix": [density(tag_dict["HOTFIX"], number_of_issues)],
        "docs": [density(tag_dict["DOCS"], number_of_issues)],
        "feature": [density(tag_dict["FEATURE"], number_of_issues)],
        "arq": [density(tag_dict["ARQ"], number_of_issues)],
        "devops": [density(tag_dict["DEVOPS"], number_of_issues)],
        "analytics": [density(tag_dict["ANALYTICS"], number_of_issues)],
        "us": [density(tag_dict["US"], number_of_issues)],
        "easy": [density(tag_dict["EASY"], number_of_issues)],
        "medium": [density(tag_dict["MEDIUM"], number_of_issues)],
        "hard": [density(tag_dict["HARD"], number_of_issues)],
        "eps": [density(tag_dict["EPS"], number_of_issues)],
        "mds": [density(tag_dict["MDS"], number_of_issues)]
    }

    issue_densities = pd.DataFrame.from_dict(issue_densities).T.reset_index()
    
    issue_densities.columns = ['density' ,'percentage']
    
    return issue_densities

# %% [markdown]
# #### BUGS RATIO

# %%
def m9(tag_dict, number_of_issues):
    
    bugs_ratio = round(((tag_dict["DOCS"] + tag_dict["FEATURE"] + tag_dict["ARQ"] + tag_dict["DEVOPS"] + tag_dict["ANALYTICS"]) / number_of_issues) * 100, 2)
    
    return bugs_ratio

# %% [markdown]
# ### Data visualization
#
# - You must do this for each of your repositories

# %%
# Out:
#          m1        m2        m3 repository             version      asc1
# 0  0.937500  0.125000  1.000000   frontend 2021-03-23 00:00:00  0.680625
# 1  0.964286  0.107143  1.000000   frontend 2021-04-18 00:00:00  0.683571
# 2  0.966667  0.066667  1.000000   frontend 2021-05-01 00:00:00  0.671000
# 3  0.966667  0.066667  1.000000   frontend 2021-05-02 00:00:00  0.671000
# 4  0.966667  0.100000  1.000000   frontend 2021-05-04 00:00:00  0.682000
# 5  0.968750  0.093750  0.937500   frontend 2021-05-09 00:00:00  0.660000
# 6  0.968750  0.093750  0.937500   frontend 2021-05-09 01:00:00  0.660000
# 7  0.968750  0.093750  0.937500   frontend 2021-05-09 02:00:00  0.660000
# 8  0.968750  0.062500  0.937500   frontend 2021-05-10 00:00:00  0.649687
# 9  0.971429  0.057143  0.971429   frontend 2021-05-10 01:00:00  0.660000

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMPLEXITY")
    plt.plot(metrics_df['m1'],linewidth=3, marker='o', markersize=10)

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMMENTS")
    plt.plot(metrics_df['m2'], linewidth=3, marker='o', markersize=10)

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:DUPLICATIONS")
    plt.plot(metrics_df['m3'], linewidth=3, marker='o', markersize=10)

# %% [markdown]
# ### Sub characteristic aggregation

# %%
psc1 = 1
pm1 = 0.33
pm2 = 0.33
pm3 = 0.33

for repository, metrics_df in repository_metrics.items(): 
    metrics_df['asc1'] = ((metrics_df['m1']*pm1)+(metrics_df['m2']*pm2)+(metrics_df['m3']*pm3))*psc1

# %%
for repository, metrics_df in repository_metrics.items(): 
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:asc1")
    plt.plot(metrics_df['asc1'], linewidth=3, marker='o', markersize=10)

# %%
all_metrics_df = pd.DataFrame()

for repository, metrics_df in repository_metrics.items():
    all_metrics_df = pd.concat([all_metrics_df, metrics_df], ignore_index=True)

all_metrics_df['ac1'] = all_metrics_df['asc1'] * 1
all_metrics_df['total'] = all_metrics_df['asc1'] * 1

# %%
all_metrics_df
# Out:
#           m1        m2        m3   repository             version      asc1  \
# 0   0.937500  0.125000  1.000000     frontend 2021-03-23 00:00:00  0.680625
# 1   0.964286  0.107143  1.000000     frontend 2021-04-18 00:00:00  0.683571
# 2   0.966667  0.066667  1.000000     frontend 2021-05-01 00:00:00  0.671000
# 3   0.966667  0.066667  1.000000     frontend 2021-05-02 00:00:00  0.671000
# 4   0.966667  0.100000  1.000000     frontend 2021-05-04 00:00:00  0.682000
# 5   0.968750  0.093750  0.937500     frontend 2021-05-09 00:00:00  0.660000
# 6   0.968750  0.093750  0.937500     frontend 2021-05-09 01:00:00  0.660000
# 7   0.968750  0.093750  0.937500     frontend 2021-05-09 02:00:00  0.660000
# 8   0.968750  0.062500  0.937500     frontend 2021-05-10 00:00:00  0.649687
